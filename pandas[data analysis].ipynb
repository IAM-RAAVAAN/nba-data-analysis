# %%
vsco!pip install pandas
# !pip install numpy

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataf = pd.read_csv("/content/drive/My Drive/Colab Notebooks/all_seasons.csv") 


fig= plt.figure()
ax=fig.add_axes([0,0,1,1])
#dataf= pd.read_csv('/run/media/swaraj/New Volume2/code/gui/pandas/all_seasons.csv')
dataf=pd.DataFrame(dataf)
print(dataf.tail(2))
age=dataf["age"]
m=np.std(age)
print('the standerd deviation is %d'% m)
sort=dataf.sort_values(by='player_height')
sort=sort.reset_index(drop=True)
print(sort)
print(sort.mean())
print(sort.describe())
ax.bar(sort['college'],sort['age'],colors='b')
# Out:
#        Unnamed: 0   player_name team_abbreviation  ...  ts_pct  ast_pct   season
# 11143       11143  Norvel Pelle               PHI  ...   0.521    0.056  2019-20
# 11144       11144   Matt Thomas               TOR  ...   0.663    0.089  2019-20
#
# [2 rows x 22 columns]
# the standerd deviation is 4
#        Unnamed: 0       player_name team_abbreviation  ...  ts_pct  ast_pct   season
# 0             401     Muggsy Bogues               CHH  ...   0.554    0.366  1996-97
# 1            1123     Muggsy Bogues               GSW  ...   0.539    0.338  1998-99
# 2            2020     Muggsy Bogues               TOR  ...   0.000    0.294  2000-01
# 3             483     Muggsy Bogues               GSW  ...   0.492    0.344  1997-98
# 4            1705     Muggsy Bogues               TOR  ...   0.517    0.266  1999-00
# ...           ...               ...               ...  ...     ...      ...      ...
# ...

# %%
###
import pandas as pd 
import numpy as np
data={
    'name': pd.series(['swaraj','nidhi','sakshi']),
    'roll no':pd.series([1,2,3])
}
data=pd.DataFrame[data]
printf(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-44b186e5ef48> in <module>()
#       2 import numpy as np
#       3 data={
# ----> 4     'name': pd.series(['swaraj','nidhi','sakshi']),
#       5     'roll no':pd.series([1,2,3])
#       6 }
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt

# %%
with open('/content/drive/My Drive/country.csv') as contry:
    thefile=pd.read_csv(contry)
    pop=[]
    af=thefile[thefile.country=='Afghanistan']
    for i in range(len(af)):
        pop.append((af.population.iloc[i]-af.population.iloc[0])/10**6)

    plt.plot(af.year,pop)

# %%
with open('/content/drive/My Drive/data.csv') as data:
    dataf=pd.read_csv(data) 
    
    count=list(dataf)
    af=dataf[dataf.Country=='Afghanistan']
    af=str(af)
    print(af[4,10])
    #print(af.loc[[1],['1960','2019']])
    
    
    
    #for keys,value in dataf.items(): 
     #   print(dataf.keys()) 
      #  print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-a4d2d6f90264> in <module>()
#       5     af=dataf[dataf.Country=='Afghanistan']
#       6     af=str(af)
# ----> 7     print(af[4,10])
#       8     #print(af.loc[[1],['1960','2019']])
#       9
#
# TypeError: string indices must be integers
